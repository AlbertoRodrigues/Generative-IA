# %%
from langgraph.graph import StateGraph, END
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
import os
from typing import Optional
from dotenv import load_dotenv
from IPython.display import  Image, display

# %%
load_dotenv()
openai_api_key=os.getenv('OPENAI_API_KEY')

# %%
llm = ChatOpenAI(model="gpt-4.1-mini-2025-04-14", openai_api_key=openai_api_key)

# Definição do estado
class State(dict):
    mensagem: str
    proposta: Optional[str]
    avaliacao: Optional[str]
    revisao_final: Optional[str]
    resultado: Optional[str]

# Função para criar estado inicial
def criar_estado_inicial(problema):
    return {
        "mensagem": problema,
        "proposta": None,
        "avaliacao": None,
        "revisao_final": None,
        "resultado": None
    }

# Nó 1: Gerar proposta
def agente_gerador(state):
    prompt = ChatPromptTemplate.from_template(
        "Proponha uma solução para o seguinte problema:\n{mensagem}\n"
        "Considere críticas anteriores: {avaliacao}"
    )
    resposta = llm.invoke(prompt.format_messages(
        mensagem=state["mensagem"],
        avaliacao=state["avaliacao"] or "Nenhuma crítica ainda."
    ))
    state["proposta"] = resposta.content.strip()
    return state

# Nó 2: Avaliar proposta
def agente_critico(state):
    prompt = ChatPromptTemplate.from_template(
        "Aqui está uma proposta: {proposta}\nAvalie se está boa ou precisa melhorar. "
        "Responda apenas com 'aprovada' ou uma crítica construtiva."
    )
    resposta = llm.invoke(prompt.format_messages(
        proposta=state["proposta"]
    ))
    state["avaliacao"] = resposta.content.strip().lower()
    return state

# Nó 3: Revisar proposta final
def revisor_final(state):
    prompt = ChatPromptTemplate.from_template(
        "Revise cuidadosamente esta proposta:\n{proposta}\n"
        "Se estiver boa, diga 'Tudo certo'. Se precisar, sugira melhorias finais."
    )
    resposta = llm.invoke(prompt.format_messages(
        proposta=state["proposta"]
    ))
    state["revisao_final"] = resposta.content.strip()
    state["resultado"] = f"Proposta finalizada: {state['proposta']} | Revisão: {state['revisao_final']}"
    return state

# Função de decisão: para onde ir depois do Crítico
def escolher_proximo(state):
    if "aprovada" in state["avaliacao"]:
        return "revisor_final"
    else:
        return "agente_gerador"

# Construção do grafo
graph = StateGraph(State)

graph.add_node("agente_gerador", agente_gerador)
graph.add_node("agente_critico", agente_critico)
graph.add_node("revisor_final", revisor_final)

graph.set_entry_point("agente_gerador")
graph.add_edge("agente_gerador", "agente_critico")
graph.add_conditional_edges("agente_critico", escolher_proximo)
graph.add_edge("revisor_final", END)

app = graph.compile()
# Out:
# C:\Users\alber\AppData\Local\Temp\ipykernel_12956\2770061743.py:1: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm = ChatOpenAI(model="gpt-4.1-mini-2025-04-14", openai_api_key=openai_api_key)

# %%
estado_inicial = criar_estado_inicial("Reduzir o tempo de resposta de um chatbot para menos de 1 segundo.")
resultado = app.invoke(estado_inicial)

print("\n--- Resultado Final ---")
print(resultado["resultado"])
# Out:
# --- Resultado Final ---
# Proposta finalizada: Para reduzir o tempo de resposta de um chatbot para menos de 1 segundo, é importante atuar em várias frentes que impactam diretamente a latência do sistema. Abaixo, proponho uma solução estruturada com medidas técnicas e arquiteturais:
#
# ### 1. Otimização do modelo de linguagem
# - **Modelos mais leves:** Utilize modelos de linguagem menores e otimizados, como distilados (DistilBERT, TinyBERT) ou versões quantizadas que mantêm boa qualidade com menor custo computacional.
# - **Pruning e quantização:** Aplique técnicas de pruning (remoção de neurônios irrelevantes) e quantização (redução da precisão dos pesos) para acelerar a inferência.
#
# ### 2. Infraestrutura e arquitetura
# - **Servidores próximos ao usuário:** Utilize CDNs ou servidores edge para executar o chatbot o mais próximo possível do usuário, reduzindo latência de rede.
# - **GPU/TPU:** Utilize hardware acelerado para inferência, como GPUs ou TPUs, para agilizar o processamento.
# - **Serviço dedicado e escalonamento:** Garanta que o serviço de chatbot tenha recursos dedicados e escalonamento automático para evitar gargalos.
#
# ### 3. Cache e pré-processamento
# - **Cache de respostas comuns:** Armazene em cache as respostas para perguntas frequentes, para resposta instantânea.
# - **Pré-processamento:** Simplifique e otimize o pipeline de pré-processamento da entrada (tokenização, limpeza), reduzindo overhead.
#
# ### 4. Pipeline assíncrono e paralelismo
# - **Processamento assíncrono:** Utilize chamadas assíncronas para não bloquear a aplicação e responder rapidamente quando possível.
# - **Paralelismo:** Execute processamento paralelo de partes do pipeline para otimizar o tempo total.
#
# ### 5. Monitoramento e otimização contínua
# - **Métricas e logs:** Monitore o tempo de resposta em produção para identificar gargalos.
# - **A/B testing:** Teste diferentes abordagens para encontrar o melhor equilíbrio entre velocidade e qualidade.
#
# ---
#
# ### Exemplo prático
# Se seu chatbot usa um modelo Transformer pesado, uma boa abordagem seria:
#
# - Substituir o modelo base por um distilado quantizado.
# - Implantar o modelo em um servidor GPU próximo do usuário.
# - Implementar cache para as perguntas mais frequentes.
# - Otimizar o código do backend para processamento assíncrono.
#
# Com essas ações combinadas, é possível atingir tempos de resposta abaixo de 1 segundo.
#
# ---
#
# Se desejar, posso ajudar a elaborar um plano detalhado de implementação para seu caso específico. | Revisão: A proposta está muito bem estruturada e cobre os principais aspectos técnicos para reduzir a latência do chatbot. Fiz algumas sugestões para deixá-la mais clara, precisa e profissional, além de pequenos ajustes de formatação e terminologia para garantir uniformidade e melhor entendimento.
#
# ---
#
# ### Revisão da proposta
#
# Para reduzir o tempo de resposta de um chatbot para menos de 1 segundo, é fundamental atuar em várias frentes que impactam diretamente a latência do sistema. A seguir, proponho uma solução estruturada com medidas técnicas e arquiteturais:
#
# ### 1. Otimização do modelo de linguagem
# - **Modelos mais leves:** Utilize modelos de linguagem menores e otimizados, como versões distiladas (DistilBERT, TinyBERT) ou quantizadas, que mantêm boa qualidade com menor custo computacional.
# - **Pruning e quantização:** Aplique técnicas de pruning (remoção de neurônios ou conexões irrelevantes) e quantização (redução da precisão dos pesos) para acelerar a inferência sem perda significativa de desempenho.
#
# ### 2. Infraestrutura e arquitetura
# - **Servidores próximos ao usuário:** Utilize CDNs ou servidores na borda (edge computing) para executar o chatbot o mais próximo possível do usuário, reduzindo a latência de rede.
# - **Hardware acelerado:** Utilize GPUs, TPUs ou outras unidades especializadas para acelerar o processamento da inferência.
# - **Serviço dedicado e escalonamento automático:** Garanta que o serviço de chatbot possua recursos dedicados e escalonamento automático para evitar gargalos em picos de demanda.
#
# ### 3. Cache e pré-processamento
# - **Cache de respostas frequentes:** Armazene em cache respostas para perguntas comuns, permitindo respostas instantâneas sem necessidade de inferência.
# - **Otimização do pré-processamento:** Simplifique e otimize o pipeline de pré-processamento da entrada (tokenização, limpeza, normalização), reduzindo overhead computacional.
#
# ### 4. Pipeline assíncrono e paralelismo
# - **Processamento assíncrono:** Utilize chamadas assíncronas para evitar bloqueio da aplicação e responder rapidamente quando possível.
# - **Paralelismo:** Execute processamento paralelo em partes do pipeline para otimizar o tempo total de resposta.
#
# ### 5. Monitoramento e otimização contínua
# - **Métricas e logs:** Monitore o tempo de resposta em produção para identificar gargalos e pontos de melhoria.
# - **Testes A/B:** Realize testes A/B para avaliar diferentes abordagens e encontrar o melhor equilíbrio entre velocidade e qualidade da resposta.
#
# ---
#
# ### Exemplo prático
#
# Se seu chatbot utiliza um modelo Transformer pesado, uma abordagem eficaz seria:
#
# - Substituir o modelo base por uma versão distilada e quantizada.
# - Implantar o modelo em servidores com GPU próximos do usuário.
# - Implementar cache para perguntas frequentes.
# - Otimizar o backend para processamento assíncrono.
#
# Com essas ações combinadas, é possível atingir tempos de resposta abaixo de 1 segundo.
#
# ---
#
# Se desejar, posso ajudar a elaborar um plano detalhado de implementação para seu caso específico.
#
# ---
#
# Se a proposta está clara e adequada, diga "Tudo certo". Caso queira, posso sugerir melhorias finais.

# %%
display(Image(app.get_graph().draw_mermaid_png()))
