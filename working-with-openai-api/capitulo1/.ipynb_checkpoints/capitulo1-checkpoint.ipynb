# %% [markdown]
# ## Nesse capítulo vamos explorar:
# - Introdução a API
# - Introdução a API da OpenAI
# - Parâmetros da API
# - Endpoints da API

# %% [markdown]
# ## Uma API é um serviço dispobilizado onde podemos fazer requisições para uma determinada tarefa e receber a resposta
#
# ![image-2.png](attachment:image-2.png)
#
# ## Na API da OpenAI nós enviamos vários parâmetros como: modelo, input e roles
# ![image-3.png](attachment:image-3.png)
#
# ## Há vários endpoints da API, podemos usar o ChatCompletion, o Completion, entre outros
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## Primeira requisição

# %%
# Import openai
import openai
openai.api_key = "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"

# %%
response = openai.Completion.create(
  # Specify the correct model
  model="gpt-3.5-turbo-instruct",
  prompt="Who developed ChatGPT?"
)

print(response)
# Out:
# {
#   "id": "cmpl-8Z0dJiL9gscggmAHDugodsdt3tvei",
#   "object": "text_completion",
#   "created": 1703354605,
#   "model": "gpt-3.5-turbo-instruct",
#   "choices": [
#     {
#       "text": "\n\nChatGPT was developed by OpenAI, a non-profit AI research company",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "length"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 6,
#     "completion_tokens": 16,
#     "total_tokens": 22
#   }
# }

# %%
# Resposta do chatgpt
print(response["choices"][0]["text"])
# Out:
# ChatGPT was developed by OpenAI, a non-profit AI research company

# %% [markdown]
# ## O chatgpt possui diversas funcionalidades como:
# - Ideação
# - Chatbot de suporte ao cliente
# - Professor particular
# - Tradução de idiomas
# - Geração de código
# - Responder perguntas
# - Classificação de texto(análise de sentimento)
# - Explicação de tópicos complexos
# - Checar incitação à violência e discurdo de ódio
